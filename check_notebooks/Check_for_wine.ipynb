# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import time
from scipy.optimize import minimize, differential_evolution
from sklearn.metrics import roc_auc_score, f1_score, accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('winequality-white.csv', sep=';')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
df.shape
# Out:
# (4898, 12)

# %%
df['quality'] = df['quality'] > 5
df.quality = df.quality.astype('int')

# %%
df.quality.value_counts()
# Out:
# 1    3258
# 0    1640
# Name: quality, dtype: int64

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        1
# 1      9.5        1
# 2     10.1        1
# 3      9.9        1
# 4      9.9        1

# %%
X = df.drop(columns=['quality']).values
y = df['quality'].values

# %%
for i in range(X.shape[1]):
    X[:,i]=(X[:,i]-X[:,i].min())/(X[:,i].max()-X[:,i].min())

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y)

# %%
X_train.shape
# Out:
# (3428, 11)

# %%
y_train.sum() / len(y_train)
# Out:
# 0.6651108518086347

# %%
from Seniority_committee import Seniority_committee

# %%
sc = Seniority_committee(N=200)
# best 200

# %%
sc.fit(X_train, y_train, optim_method='TNC', verbose=2)
# Out:
# Making hyperplane number 1
# X_train.shape[0] = 3428
# k = 10
# L = 1024
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.19725925327652
# Time taken for optimization: 5.813992261886597
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.15611322339336026
# Time taken for optimization: 6.102990388870239
# X_1.shape[0] = 73
# X_0.shape[0] = 35
# Cutted data shape is not enough
#
# k = 9
# L = 512
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.5688036458061141
# Time taken for optimization: 5.418992042541504
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.1459139629645308
# Time taken for optimization: 5.341994047164917
# X_1.shape[0] = 113
# X_0.shape[0] = 23
# Cutted data shape is not enough
#
# k = 8
# L = 256
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.11787306426035041
# Time taken for optimization: 5.208994388580322
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.21436774147548845
# Time taken for optimization: 5.239995956420898
# X_1.shape[0] = 28
# X_0.shape[0] = 29
# Cutted data shape is not enough
#
# k = 7
# L = 128
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.24358582011164345
# Time taken for optimization: 6.206990480422974
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.17283198392503196
# Time taken for optimization: 5.1809937953948975
# X_1.shape[0] = 68
# X_0.shape[0] = 38
# Cutted data shape is not enough
#
# k = 6
# L = 64
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.7598474235250157
# Time taken for optimization: 6.959991931915283
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.1438073040857442
# Time taken for optimization: 4.885993480682373
# X_1.shape[0] = 221
# X_0.shape[0] = 23
#
# Making hyperplane number 2
# X_train.shape[0] = 3207
# k = 10
# L = 1024
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.14458991049268594
# Time taken for optimization: 4.765215158462524
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.07179628535221377
# Time taken for optimization: 5.3381195068359375
# X_1.shape[0] = 55
# X_0.shape[0] = 18
# Cutted data shape is not enough
#
# k = 9
# L = 512
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.2227345311712534
# Time taken for optimization: 3.9604287147521973
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.14341645358733424
# Time taken for optimization: 5.495367765426636
# X_1.shape[0] = 50
# X_0.shape[0] = 22
# Cutted data shape is not enough
#
# k = 8
# L = 256
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.27682523531273684
# Time taken for optimization: 5.106994152069092
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.27202956361770286
# Time taken for optimization: 5.625993251800537
# X_1.shape[0] = 58
# X_0.shape[0] = 41
# Cutted data shape is not enough
#
# k = 7
# L = 128
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.21038913222474764
# Time taken for optimization: 5.091995000839233
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.0755483031361917
# Time taken for optimization: 6.4659929275512695
# X_1.shape[0] = 60
# X_0.shape[0] = 14
# Cutted data shape is not enough
#
# k = 6
# L = 64
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.27580987307300064
# Time taken for optimization: 5.663994312286377
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.1639758595759297
# Time taken for optimization: 7.3879899978637695
# X_1.shape[0] = 44
# X_0.shape[0] = 23
# Cutted data shape is not enough
#
# k = 5
# L = 32
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.6092785594731551
# Time taken for optimization: 6.815991163253784
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.128272130664574
# Time taken for optimization: 5.78799295425415
# X_1.shape[0] = 159
# X_0.shape[0] = 16
# Cutted data shape is not enough
#
# k = 4
# L = 16
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -126.41191810719485
# Time taken for optimization: 7.930992603302002
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.4444962748646456
# Time taken for optimization: 7.72899055480957
# X_1.shape[0] = 243
# X_0.shape[0] = 35
#
# Making hyperplane number 3
# X_train.shape[0] = 2964
# k = 10
# L = 1024
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.16496345026483444
# Time taken for optimization: 5.3049962520599365
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.19086319830197668
# Time taken for optimization: 11.355988264083862
# X_1.shape[0] = 4
# X_0.shape[0] = 7
# Cutted data shape is not enough
#
# k = 9
# L = 512
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.08396083681202775
# Time taken for optimization: 5.714657783508301
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.13841111974155024
# Time taken for optimization: 6.172827959060669
# X_1.shape[0] = 10
# X_0.shape[0] = 21
# Cutted data shape is not enough
#
# k = 8
# L = 256
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.05666089829525839
# Time taken for optimization: 4.125868320465088
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.08114408577807727
# Time taken for optimization: 6.1279942989349365
# X_1.shape[0] = 29
# X_0.shape[0] = 20
# Cutted data shape is not enough
#
# k = 7
# L = 128
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.0856667953796961
# Time taken for optimization: 4.70978856086731
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.17909337150799526
# Time taken for optimization: 6.105589151382446
# X_1.shape[0] = 1
# X_0.shape[0] = 33
# Cutted data shape is not enough
#
# k = 6
# L = 64
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.5102721043398929
# Time taken for optimization: 6.472106218338013
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.09263100518341022
# Time taken for optimization: 6.079993724822998
# X_1.shape[0] = 7
# X_0.shape[0] = 11
# Cutted data shape is not enough
#
# k = 5
# L = 32
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.22792005549696467
# Time taken for optimization: 5.9159934520721436
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.17184731169214262
# Time taken for optimization: 6.224991083145142
# X_1.shape[0] = 9
# X_0.shape[0] = 13
# Cutted data shape is not enough
#
# k = 4
# L = 16
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.6916401352106444
# Time taken for optimization: 7.831989765167236
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -5.781026136217037
# Time taken for optimization: 12.547986507415771
# X_1.shape[0] = 10
# X_0.shape[0] = 15
# Cutted data shape is not enough
#
# k = 3
# L = 8
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -117.9633362721303
# Time taken for optimization: 9.333986759185791
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -28.0
# Time taken for optimization: 11.035987615585327
# X_1.shape[0] = 502
# X_0.shape[0] = 37
#
# Making hyperplane number 4
# X_train.shape[0] = 2462
# k = 10
# L = 1024
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.1446745440627946
# Time taken for optimization: 5.257993459701538
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.08649675020099917
# Time taken for optimization: 6.193994760513306
# X_1.shape[0] = 42
# X_0.shape[0] = 9
# Cutted data shape is not enough
#
# k = 9
# L = 512
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.05855548076003169
# Time taken for optimization: 5.569993019104004
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.13180109544099253
# Time taken for optimization: 5.458991765975952
# X_1.shape[0] = 5
# X_0.shape[0] = 25
# Cutted data shape is not enough
#
# k = 8
# L = 256
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.18427607508426053
# Time taken for optimization: 5.6819963455200195
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.14382155886423004
# Time taken for optimization: 5.28855037689209
# X_1.shape[0] = 5
# X_0.shape[0] = 13
# Cutted data shape is not enough
#
# k = 7
# L = 128
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.09438427750563394
# Time taken for optimization: 4.180994987487793
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.20031825757201663
# Time taken for optimization: 5.97799277305603
# X_1.shape[0] = 8
# X_0.shape[0] = 27
# Cutted data shape is not enough
#
# k = 6
# L = 64
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.08893759257038036
# Time taken for optimization: 5.5742621421813965
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.18454517900570272
# Time taken for optimization: 6.48104190826416
# X_1.shape[0] = 5
# X_0.shape[0] = 27
# Cutted data shape is not enough
#
# k = 5
# L = 32
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -5.0
# Time taken for optimization: 6.036993503570557
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.09213910705296804
# Time taken for optimization: 5.9069929122924805
# X_1.shape[0] = 5
# X_0.shape[0] = 12
# Cutted data shape is not enough
#
# k = 4
# L = 16
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -7.224020545692138
# Time taken for optimization: 5.935993194580078
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.47863809638021587
# Time taken for optimization: 7.808990478515625
# X_1.shape[0] = 8
# X_0.shape[0] = 38
# Cutted data shape is not enough
#
# k = 3
# L = 8
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -3.722030409832408
# Time taken for optimization: 6.3869922161102295
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -42.12261994618688
# Time taken for optimization: 8.494987726211548
# X_1.shape[0] = 5
# X_0.shape[0] = 48
# Cutted data shape is not enough
#
# k = 2
# L = 4
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -91.95620789446568
# Time taken for optimization: 7.298989772796631
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -87.8596861417007
# Time taken for optimization: 9.864988803863525
# X_1.shape[0] = 343
# X_0.shape[0] = 171
#
# Making hyperplane number 5
# X_train.shape[0] = 2119
# k = 10
# L = 1024
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.07371182892717201
# Time taken for optimization: 3.2649970054626465
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.07855390207675887
# Time taken for optimization: 4.61499547958374
# X_1.shape[0] = 7
# X_0.shape[0] = 20
# Cutted data shape is not enough
#
# k = 9
# L = 512
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.0733727790813804
# Time taken for optimization: 3.67509126663208
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.11346362754045064
# Time taken for optimization: 4.842635869979858
# X_1.shape[0] = 4
# X_0.shape[0] = 20
# Cutted data shape is not enough
#
# k = 8
# L = 256
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.10103043053979036
# Time taken for optimization: 3.8908567428588867
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.16096709380437335
# Time taken for optimization: 5.119251251220703
# X_1.shape[0] = 7
# X_0.shape[0] = 23
# Cutted data shape is not enough
#
# k = 7
# L = 128
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -3.0
# Time taken for optimization: 3.598275661468506
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.10917055388963062
# Time taken for optimization: 5.245992422103882
# X_1.shape[0] = 3
# X_0.shape[0] = 14
# Cutted data shape is not enough
#
# k = 6
# L = 64
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.11464486969307187
# Time taken for optimization: 4.05744194984436
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.17063521605421683
# Time taken for optimization: 5.277815341949463
# X_1.shape[0] = 7
# X_0.shape[0] = 17
# Cutted data shape is not enough
#
# k = 5
# L = 32
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.1301137108110756
# Time taken for optimization: 5.165499925613403
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.11178000557312193
# Time taken for optimization: 4.943578720092773
# X_1.shape[0] = 8
# X_0.shape[0] = 19
# Cutted data shape is not enough
#
# k = 4
# L = 16
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.37982476014909267
# Time taken for optimization: 4.617246627807617
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.8678220616556838
# Time taken for optimization: 6.054440259933472
# X_1.shape[0] = 10
# X_0.shape[0] = 51
# Cutted data shape is not enough
#
# k = 3
# L = 8
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -5.0
# Time taken for optimization: 4.87532114982605
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -37.03927351037843
# Time taken for optimization: 7.282252550125122
# X_1.shape[0] = 5
# X_0.shape[0] = 72
# Cutted data shape is not enough
#
# k = 2
# L = 4
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -12.413482649748083
# Time taken for optimization: 5.8709917068481445
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -75.81288742842781
# Time taken for optimization: 8.768992185592651
# X_1.shape[0] = 18
# X_0.shape[0] = 241
#
# Making hyperplane number 6
# X_train.shape[0] = 1878
# k = 10
# L = 1024
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.07923476145794259
# Time taken for optimization: 3.1449949741363525
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.037415436299899046
# Time taken for optimization: 4.127994537353516
# X_1.shape[0] = 3
# X_0.shape[0] = 10
# Cutted data shape is not enough
#
# k = 9
# L = 512
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.059736873820452216
# Time taken for optimization: 3.507996082305908
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.0683369310877942
# Time taken for optimization: 3.549994945526123
# X_1.shape[0] = 5
# X_0.shape[0] = 20
# Cutted data shape is not enough
#
# k = 8
# L = 256
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.092200284768443
# Time taken for optimization: 3.719996452331543
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.05048494231888591
# Time taken for optimization: 4.027993679046631
# X_1.shape[0] = 7
# X_0.shape[0] = 10
# Cutted data shape is not enough
#
# k = 7
# L = 128
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.08896052710766211
# Time taken for optimization: 3.8499956130981445
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.04524119994396009
# Time taken for optimization: 3.8469953536987305
# X_1.shape[0] = 6
# X_0.shape[0] = 4
# Cutted data shape is not enough
#
# k = 6
# L = 64
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -3.0
# Time taken for optimization: 4.921994209289551
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.26367427064727145
# Time taken for optimization: 3.3889968395233154
# X_1.shape[0] = 3
# X_0.shape[0] = 15
# Cutted data shape is not enough
#
# k = 5
# L = 32
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -1.0
# Time taken for optimization: 4.479993581771851
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.06152010228435982
# Time taken for optimization: 4.039996862411499
# X_1.shape[0] = 1
# X_0.shape[0] = 12
# Cutted data shape is not enough
#
# k = 4
# L = 16
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -10.078258948088527
# Time taken for optimization: 5.306993722915649
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.10316847895435674
# Time taken for optimization: 4.792995929718018
# X_1.shape[0] = 11
# X_0.shape[0] = 25
# Cutted data shape is not enough
#
# k = 3
# L = 8
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -7.167876095190714
# Time taken for optimization: 6.601991176605225
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.24480062500315122
# Time taken for optimization: 4.876995325088501
# X_1.shape[0] = 8
# X_0.shape[0] = 15
# Cutted data shape is not enough
#
# k = 2
# L = 4
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -19.758271106945998
# Time taken for optimization: 4.669994115829468
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -14.258249170928657
# Time taken for optimization: 5.932995557785034
# X_1.shape[0] = 32
# X_0.shape[0] = 54
# Cutted data shape is not enough
#
# k = 1
# L = 2
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -129.93261989347684
# Time taken for optimization: 8.512989282608032
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -60.22219909287769
# Time taken for optimization: 7.405991315841675
# X_1.shape[0] = 567
# X_0.shape[0] = 242
#
# Making hyperplane number 7
# X_train.shape[0] = 1311
# k = 10
# L = 1024
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.13932298072411234
# Time taken for optimization: 2.1269967555999756
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.03918307768305654
# Time taken for optimization: 1.6999971866607666
# X_1.shape[0] = 8
# X_0.shape[0] = 9
# Cutted data shape is not enough
#
# k = 9
# L = 512
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.09772625030995437
# Time taken for optimization: 2.0309975147247314
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.03876357460880362
# Time taken for optimization: 2.141998529434204
# X_1.shape[0] = 10
# X_0.shape[0] = 6
# Cutted data shape is not enough
#
# k = 8
# L = 256
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.1083852136722019
# Time taken for optimization: 2.5229973793029785
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.07429364663825896
# Time taken for optimization: 1.9429996013641357
# X_1.shape[0] = 5
# X_0.shape[0] = 11
# Cutted data shape is not enough
#
# k = 7
# L = 128
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.26978430560511213
# Time taken for optimization: 1.6999964714050293
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.06161240721953613
# Time taken for optimization: 2.07399845123291
# X_1.shape[0] = 7
# X_0.shape[0] = 10
# Cutted data shape is not enough
#
# k = 6
# L = 64
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.09066905971509227
# Time taken for optimization: 1.8829984664916992
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -1.0277263552492424
# Time taken for optimization: 2.136996269226074
# X_1.shape[0] = 7
# X_0.shape[0] = 3
# Cutted data shape is not enough
#
# k = 5
# L = 32
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.29544846062074404
# Time taken for optimization: 2.0959982872009277
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.05163289873988588
# Time taken for optimization: 1.9919960498809814
# X_1.shape[0] = 9
# X_0.shape[0] = 8
# Cutted data shape is not enough
#
# k = 4
# L = 16
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -2.2686912833012296
# Time taken for optimization: 2.8459970951080322
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.28376552581964654
# Time taken for optimization: 2.6109986305236816
# X_1.shape[0] = 11
# X_0.shape[0] = 8
# Cutted data shape is not enough
#
# k = 3
# L = 8
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -8.275932149211723
# Time taken for optimization: 3.2759969234466553
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.10137347083355316
# Time taken for optimization: 2.194995880126953
# X_1.shape[0] = 10
# X_0.shape[0] = 16
# Cutted data shape is not enough
#
# k = 2
# L = 4
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -8.0
# Time taken for optimization: 2.6919970512390137
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -12.538952780245753
# Time taken for optimization: 4.087994337081909
# X_1.shape[0] = 8
# X_0.shape[0] = 15
# Cutted data shape is not enough
#
# k = 1
# L = 2
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -25.586962356960644
# Time taken for optimization: 3.9369945526123047
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -26.1883582561072
# Time taken for optimization: 3.5699968338012695
# X_1.shape[0] = 96
# X_0.shape[0] = 153
# Cutted data shape is not enough
#
# k = 0
# L = 1
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -127.20706121352987
# Time taken for optimization: 6.673994064331055
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -181.85084906917973
# Time taken for optimization: 4.3539934158325195
# X_1.shape[0] = 738
# X_0.shape[0] = 722
#
# Making hyperplane number 8
# X_train.shape[0] = 573
# k = 10
# L = 1024
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.060572715429159124
# Time taken for optimization: 1.248997688293457
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.14361526215196832
# Time taken for optimization: 1.5449979305267334
# X_1.shape[0] = 4
# X_0.shape[0] = 11
# Cutted data shape is not enough
#
# k = 9
# L = 512
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.08222177512665227
# Time taken for optimization: 1.7769992351531982
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.12869577592077133
# Time taken for optimization: 1.240999698638916
# X_1.shape[0] = 4
# X_0.shape[0] = 15
# Cutted data shape is not enough
#
# k = 8
# L = 256
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.06991235551062738
# Time taken for optimization: 1.5319952964782715
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.0373708457493838
# Time taken for optimization: 1.5559985637664795
# X_1.shape[0] = 1
# X_0.shape[0] = 13
# Cutted data shape is not enough
#
# k = 7
# L = 128
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.08523285660479038
# Time taken for optimization: 1.5679993629455566
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.11180706528427123
# Time taken for optimization: 1.777996301651001
# X_1.shape[0] = 1
# X_0.shape[0] = 27
# Cutted data shape is not enough
#
# k = 6
# L = 64
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.18308285922281256
# Time taken for optimization: 1.797997236251831
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.07112041371500172
# Time taken for optimization: 1.860999584197998
# X_1.shape[0] = 2
# X_0.shape[0] = 16
# Cutted data shape is not enough
#
# k = 5
# L = 32
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -1.0
# Time taken for optimization: 1.7719967365264893
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.1141319380928561
# Time taken for optimization: 1.9809980392456055
# X_1.shape[0] = 1
# X_0.shape[0] = 12
# Cutted data shape is not enough
#
# k = 4
# L = 16
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.6974077606915534
# Time taken for optimization: 2.312999725341797
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.21056570665730245
# Time taken for optimization: 2.1169939041137695
# X_1.shape[0] = 4
# X_0.shape[0] = 7
# Cutted data shape is not enough
#
# k = 3
# L = 8
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -1.0323801481898298
# Time taken for optimization: 1.6689982414245605
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -15.0
# Time taken for optimization: 2.1279969215393066
# X_1.shape[0] = 2
# X_0.shape[0] = 15
# Cutted data shape is not enough
#
# k = 2
# L = 4
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -2.572766231513809
# Time taken for optimization: 1.752997875213623
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -18.955330729306638
# Time taken for optimization: 2.5109963417053223
# X_1.shape[0] = 6
# X_0.shape[0] = 48
# Cutted data shape is not enough
#
# k = 1
# L = 2
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -12.642845398679672
# Time taken for optimization: 3.013997793197632
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -78.37469964268415
# Time taken for optimization: 3.3799943923950195
# X_1.shape[0] = 28
# X_0.shape[0] = 241
#
# Time taken to fit the model: 653.0509071350098

# %%
train_proba = sc.predict_proba(X_train)
test_proba = sc.predict_proba(X_test)
train_preds = sc.predict(X_train)
test_preds = sc.predict(X_test)
print('Train Gini = {}'.format(2 * roc_auc_score(y_train, train_proba) - 1))
print('Test Gini = {}'.format(2 * roc_auc_score(y_test, test_proba) - 1))
print('Train F1 = {}'.format(f1_score(y_train, train_preds)))
print('Test F1 = {}'.format(f1_score(y_test, test_preds)))
print('Train accuracy = {}'.format(accuracy_score(y_train, train_preds)))
print('Test accuracy = {}'.format(accuracy_score(y_test, test_preds)))
# Out:
# Time taken to predict the targets: 2.436026096343994
# Time taken to predict the targets: 1.0483648777008057
# Train Gini = 0.6298830154654929
# Test Gini = 0.5878244135202089

# %%
tree = DecisionTreeClassifier(max_depth=3)
tree.fit(X_train, y_train)
train_proba = tree.predict_proba(X_train)
test_proba = tree.predict_proba(X_test)
train_preds = tree.predict(X_train)
test_preds = tree.predict(X_test)
print('Train Gini = {}'.format(2 * roc_auc_score(y_train, train_proba[:, 1]) - 1))
print('Test Gini = {}'.format(2 * roc_auc_score(y_test, test_proba[:, 1]) - 1))
print('Train F1 = {}'.format(f1_score(y_train, train_preds)))
print('Test F1 = {}'.format(f1_score(y_test, test_preds)))
print('Train Accuracy = {}'.format(accuracy_score(y_train, train_preds)))
print('Test Accuracy = {}'.format(accuracy_score(y_test, test_preds)))
# Out:
# Train Gini = 0.5722985054098662
# Test Gini = 0.5685009227392888

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
train_proba = logreg.predict_proba(X_train)
test_proba = logreg.predict_proba(X_test)
train_preds = logreg.predict(X_train)
test_preds = logreg.predict(X_test)
print('Train Gini = {}'.format(2 * roc_auc_score(y_train, train_proba[:, 1]) - 1))
print('Test Gini = {}'.format(2 * roc_auc_score(y_test, test_proba[:, 1]) - 1))
print('Train F1 = {}'.format(f1_score(y_train, train_preds)))
print('Test F1 = {}'.format(f1_score(y_test, test_preds)))
print('Train Accuracy = {}'.format(accuracy_score(y_train, train_preds)))
print('Test Accuracy = {}'.format(accuracy_score(y_test, test_preds)))
# Out:
# Train Gini = 0.604043645699615
# Test Gini = 0.5734159642209922

# %%
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
train_proba = rf.predict_proba(X_train)
test_proba = rf.predict_proba(X_test)
train_preds = rf.predict(X_train)
test_preds = rf.predict(X_test)
print('Train Gini = {}'.format(2 * roc_auc_score(y_train, train_proba[:, 1]) - 1))
print('Test Gini = {}'.format(2 * roc_auc_score(y_test, test_proba[:, 1]) - 1))
print('Train F1 = {}'.format(f1_score(y_train, train_preds)))
print('Test F1 = {}'.format(f1_score(y_test, test_preds)))
print('Train Accuracy = {}'.format(accuracy_score(y_train, train_preds)))
print('Test Accuracy = {}'.format(accuracy_score(y_test, test_preds)))
# Out:
# Train Gini = 1.0
# Test Gini = 0.7996159409446857

# %%
from lightgbm import LGBMClassifier
lgbm = LGBMClassifier()
lgbm.fit(X_train, y_train)
train_proba = lgbm.predict_proba(X_train)
test_proba = lgbm.predict_proba(X_test)
train_preds = lgbm.predict(X_train)
test_preds = lgbm.predict(X_test)
print('Train Gini = {}'.format(2 * roc_auc_score(y_train, train_proba[:, 1]) - 1))
print('Test Gini = {}'.format(2 * roc_auc_score(y_test, test_proba[:, 1]) - 1))
print('Train F1 = {}'.format(f1_score(y_train, train_preds)))
print('Test F1 = {}'.format(f1_score(y_test, test_preds)))
print('Train Accuracy = {}'.format(accuracy_score(y_train, train_preds)))
print('Test Accuracy = {}'.format(accuracy_score(y_test, test_preds)))
# Out:
# Train Gini = 0.9889036615930069
# Test Gini = 0.7405855653648561
