# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import time
from scipy.optimize import minimize, differential_evolution
from sklearn.metrics import roc_auc_score, f1_score, accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# %%
df = pd.read_table('magic04.data', sep=',', header=None)

# %%
df
# Out:
#              0         1       2       3       4         5         6   \
# 0       28.7967   16.0021  2.6449  0.3918  0.1982   27.7004   22.0110
# 1       31.6036   11.7235  2.5185  0.5303  0.3773   26.2722   23.8238
# 2      162.0520  136.0310  4.0612  0.0374  0.0187  116.7410  -64.8580
# 3       23.8172    9.5728  2.3385  0.6147  0.3922   27.2107   -6.4633
# 4       75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277   28.5525
# ...         ...       ...     ...     ...     ...       ...       ...
# 19015   21.3846   10.9170  2.6161  0.5857  0.3934   15.2618   11.5245
# 19016   28.9452    6.7020  2.2672  0.5351  0.2784   37.0816   13.1853
# 19017   75.4455   47.5305  3.4483  0.1417  0.0549   -9.3561   41.0562
# 19018  120.5135   76.9018  3.9939  0.0944  0.0683    5.8043  -93.5224
# 19019  187.1814   53.0014  3.2093  0.2876  0.1539 -167.3125 -168.4558
#
#             7        8         9  10
# 0      -8.2027  40.0920   81.8828  g
# 1      -9.9574   6.3609  205.2610  g
# 2     -45.2160  76.9600  256.7880  g
# 3      -7.1513  10.4490  116.7370  g
# 4      21.8393   4.6480  356.4620  g
# ...        ...      ...       ... ..
# 19015   2.8766   2.4229  106.8258  h
# 19016  -2.9632  86.7975  247.4560  h
# 19017  -9.4662  30.2987  256.5166  h
# 19018 -63.8389  84.6874  408.3166  h
# 19019  31.4755  52.7310  272.3174  h
#
# [19020 rows x 11 columns]

# %%
df[10] = (df[10] == 'g').astype('int')

# %%
df[10].value_counts()
# Out:
# 1    12332
# 0     6688
# Name: 10, dtype: int64

# %%
X = df.drop(columns=[10]).values
y = df[10].values

# %%
for i in range(X.shape[1]):
    X[:,i]=(X[:,i]-X[:,i].min())/(X[:,i].max()-X[:,i].min())

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y)

# %%
X_train.shape
# Out:
# (13314, 10)

# %%
y_train.sum() / len(y_train)
# Out:
# 0.6483400931350458

# %%
from Seniority_committee import Seniority_committee
sc = Seniority_committee(N=200)
sc.fit(X_train, y_train, optim_method='TNC', verbose=2)
# Out:
# Making hyperplane number 1
# X_train.shape[0] = 13314
# k = 7
# L = 128
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -20.296138002937717
# Time taken for optimization: 14.135995864868164
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -384.68221888436824
# Time taken for optimization: 26.351001262664795
# X_1.shape[0] = 1285
# X_0.shape[0] = 477
#
# Making hyperplane number 2
# X_train.shape[0] = 12029
# k = 7
# L = 128
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.040114076921257534
# Time taken for optimization: 8.122000932693481
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -457.78034459266496
# Time taken for optimization: 22.78400230407715
# X_1.shape[0] = 24
# X_0.shape[0] = 515
#
# Making hyperplane number 3
# X_train.shape[0] = 11514
# k = 7
# L = 128
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.02505185271909132
# Time taken for optimization: 9.217000961303711
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -1.7276935319455875
# Time taken for optimization: 23.339000940322876
# X_1.shape[0] = 13
# X_0.shape[0] = 73
# Cutted data shape is not enough
#
# k = 6
# L = 64
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.11840233525536223
# Time taken for optimization: 9.239002227783203
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -2.2351910761407385
# Time taken for optimization: 18.304997205734253
# X_1.shape[0] = 90
# X_0.shape[0] = 104
# Cutted data shape is not enough
#
# k = 5
# L = 32
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.04214421031000336
# Time taken for optimization: 7.410001516342163
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -107.1837521360549
# Time taken for optimization: 17.83400058746338
# X_1.shape[0] = 15
# X_0.shape[0] = 493
#
# Making hyperplane number 4
# X_train.shape[0] = 11021
# k = 7
# L = 128
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.05447654269331287
# Time taken for optimization: 6.895001411437988
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.4455364818276165
# Time taken for optimization: 12.029000759124756
# X_1.shape[0] = 11
# X_0.shape[0] = 62
# Cutted data shape is not enough
#
# k = 6
# L = 64
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.044560675453577725
# Time taken for optimization: 6.435999631881714
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -2.170972426829906
# Time taken for optimization: 14.815001249313354
# X_1.shape[0] = 18
# X_0.shape[0] = 126
# Cutted data shape is not enough
#
# k = 5
# L = 32
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.019223443081975624
# Time taken for optimization: 7.493001222610474
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -54.72635247662354
# Time taken for optimization: 14.408999681472778
# X_1.shape[0] = 6
# X_0.shape[0] = 108
# Cutted data shape is not enough
#
# k = 4
# L = 16
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.024492481303458238
# Time taken for optimization: 7.47499942779541
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -106.4173190513016
# Time taken for optimization: 17.746000051498413
# X_1.shape[0] = 18
# X_0.shape[0] = 160
# Cutted data shape is not enough
#
# k = 3
# L = 8
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -1288.079916324758
# Time taken for optimization: 15.459000825881958
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -161.86030138220826
# Time taken for optimization: 23.705999612808228
# X_1.shape[0] = 3420
# X_0.shape[0] = 248
#
# Making hyperplane number 5
# X_train.shape[0] = 7601
# k = 7
# L = 128
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.03258486081048715
# Time taken for optimization: 5.2829999923706055
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.5873547661195342
# Time taken for optimization: 10.606000185012817
# X_1.shape[0] = 17
# X_0.shape[0] = 49
# Cutted data shape is not enough
#
# k = 6
# L = 64
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.03389262686699141
# Time taken for optimization: 4.990000247955322
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.5270844446081008
# Time taken for optimization: 11.360999822616577
# X_1.shape[0] = 6
# X_0.shape[0] = 61
# Cutted data shape is not enough
#
# k = 5
# L = 32
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.0580278814087727
# Time taken for optimization: 6.479004383087158
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -79.74200155047978
# Time taken for optimization: 13.35999584197998
# X_1.shape[0] = 19
# X_0.shape[0] = 81
# Cutted data shape is not enough
#
# k = 4
# L = 16
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.10630701756117819
# Time taken for optimization: 7.27899956703186
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -133.93279900430764
# Time taken for optimization: 13.792000770568848
# X_1.shape[0] = 45
# X_0.shape[0] = 135
# Cutted data shape is not enough
#
# k = 3
# L = 8
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -55.41128903954672
# Time taken for optimization: 8.23400068283081
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -160.45893987399677
# Time taken for optimization: 15.517001628875732
# X_1.shape[0] = 209
# X_0.shape[0] = 244
#
# Making hyperplane number 6
# X_train.shape[0] = 7357
# k = 7
# L = 128
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.11571563413916687
# Time taken for optimization: 6.681997299194336
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.13784127735225402
# Time taken for optimization: 9.223999977111816
# X_1.shape[0] = 15
# X_0.shape[0] = 29
# Cutted data shape is not enough
#
# k = 6
# L = 64
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.06735494778464675
# Time taken for optimization: 6.568000555038452
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.08399256008141551
# Time taken for optimization: 11.58000373840332
# X_1.shape[0] = 11
# X_0.shape[0] = 24
# Cutted data shape is not enough
#
# k = 5
# L = 32
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.025011685940230954
# Time taken for optimization: 6.397999048233032
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.21523001477470963
# Time taken for optimization: 10.893998622894287
# X_1.shape[0] = 9
# X_0.shape[0] = 39
# Cutted data shape is not enough
#
# k = 4
# L = 16
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.1511665363399068
# Time taken for optimization: 9.22464108467102
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -2.48437264308701
# Time taken for optimization: 12.197929382324219
# X_1.shape[0] = 71
# X_0.shape[0] = 519
#
# Making hyperplane number 7
# X_train.shape[0] = 6838
# k = 7
# L = 128
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.05840247378748763
# Time taken for optimization: 6.138525009155273
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.1187508738486546
# Time taken for optimization: 6.977739095687866
# X_1.shape[0] = 12
# X_0.shape[0] = 12
# Cutted data shape is not enough
#
# k = 6
# L = 64
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.054150791798005644
# Time taken for optimization: 7.210655689239502
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.07039612307193452
# Time taken for optimization: 7.239445447921753
# X_1.shape[0] = 24
# X_0.shape[0] = 17
# Cutted data shape is not enough
#
# k = 5
# L = 32
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.10273152468534874
# Time taken for optimization: 6.955260515213013
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.22507753817184345
# Time taken for optimization: 9.24599814414978
# X_1.shape[0] = 12
# X_0.shape[0] = 34
# Cutted data shape is not enough
#
# k = 4
# L = 16
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.15954290983684224
# Time taken for optimization: 7.455000400543213
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.33279799415279043
# Time taken for optimization: 9.416999340057373
# X_1.shape[0] = 14
# X_0.shape[0] = 35
# Cutted data shape is not enough
#
# k = 3
# L = 8
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -54.17017741773647
# Time taken for optimization: 11.732000350952148
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -12.397139873286498
# Time taken for optimization: 12.938949584960938
# X_1.shape[0] = 329
# X_0.shape[0] = 18
#
# Making hyperplane number 8
# X_train.shape[0] = 6509
# k = 7
# L = 128
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.04216738563384794
# Time taken for optimization: 7.949407577514648
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.12526889576641978
# Time taken for optimization: 10.1083402633667
# X_1.shape[0] = 6
# X_0.shape[0] = 12
# Cutted data shape is not enough
#
# k = 6
# L = 64
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.01575207020593088
# Time taken for optimization: 6.849001407623291
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.07859037613916615
# Time taken for optimization: 8.628996849060059
# X_1.shape[0] = 3
# X_0.shape[0] = 25
# Cutted data shape is not enough
#
# k = 5
# L = 32
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.06491593658895467
# Time taken for optimization: 9.907001495361328
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.32844278676051364
# Time taken for optimization: 9.500800132751465
# X_1.shape[0] = 17
# X_0.shape[0] = 21
# Cutted data shape is not enough
#
# k = 4
# L = 16
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.08526698064768944
# Time taken for optimization: 8.770009279251099
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.1446271680018576
# Time taken for optimization: 12.266699075698853
# X_1.shape[0] = 16
# X_0.shape[0] = 19
# Cutted data shape is not enough
#
# k = 3
# L = 8
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -4.597371802298213
# Time taken for optimization: 8.76099967956543
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -13.228260179424499
# Time taken for optimization: 19.040001392364502
# X_1.shape[0] = 8
# X_0.shape[0] = 25
# Cutted data shape is not enough
#
# k = 2
# L = 4
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -481.7713468369144
# Time taken for optimization: 12.258001565933228
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -80.0349585113141
# Time taken for optimization: 17.109002828598022
# X_1.shape[0] = 2248
# X_0.shape[0] = 220
#
# Making hyperplane number 9
# X_train.shape[0] = 4261
# k = 7
# L = 128
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.06077982505616043
# Time taken for optimization: 6.944000482559204
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.1019961251520532
# Time taken for optimization: 7.474000453948975
# X_1.shape[0] = 21
# X_0.shape[0] = 13
# Cutted data shape is not enough
#
# k = 6
# L = 64
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.03807215931051435
# Time taken for optimization: 7.585999488830566
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.1255008584176863
# Time taken for optimization: 17.298001050949097
# X_1.shape[0] = 12
# X_0.shape[0] = 19
# Cutted data shape is not enough
#
# k = 5
# L = 32
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.1467496389470212
# Time taken for optimization: 19.317627429962158
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.16415969397428876
# Time taken for optimization: 11.190001010894775
# X_1.shape[0] = 12
# X_0.shape[0] = 32
# Cutted data shape is not enough
#
# k = 4
# L = 16
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.3245623312915514
# Time taken for optimization: 11.811000108718872
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.740138644270503
# Time taken for optimization: 10.039001226425171
# X_1.shape[0] = 33
# X_0.shape[0] = 63
# Cutted data shape is not enough
#
# k = 3
# L = 8
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.37892745700416963
# Time taken for optimization: 8.708000183105469
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -38.920990996256045
# Time taken for optimization: 12.875999450683594
# X_1.shape[0] = 28
# X_0.shape[0] = 59
# Cutted data shape is not enough
#
# k = 2
# L = 4
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -58.533909896355425
# Time taken for optimization: 9.210998773574829
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -289.0070523340021
# Time taken for optimization: 14.032004833221436
# X_1.shape[0] = 133
# X_0.shape[0] = 903
#
# Making hyperplane number 10
# X_train.shape[0] = 3358
# k = 7
# L = 128
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.021446877979734838
# Time taken for optimization: 5.2759997844696045
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.1060216956821901
# Time taken for optimization: 8.292000532150269
# X_1.shape[0] = 14
# X_0.shape[0] = 18
# Cutted data shape is not enough
#
# k = 6
# L = 64
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.12575357171649965
# Time taken for optimization: 6.452999591827393
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.1774191727060554
# Time taken for optimization: 7.242998123168945
# X_1.shape[0] = 12
# X_0.shape[0] = 30
# Cutted data shape is not enough
#
# k = 5
# L = 32
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.06758774903290327
# Time taken for optimization: 6.126003742218018
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.2015709803697034
# Time taken for optimization: 11.003998041152954
# X_1.shape[0] = 13
# X_0.shape[0] = 31
# Cutted data shape is not enough
#
# k = 4
# L = 16
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.033282652787766286
# Time taken for optimization: 5.341999769210815
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -19.59457962527653
# Time taken for optimization: 7.663002014160156
# X_1.shape[0] = 5
# X_0.shape[0] = 26
# Cutted data shape is not enough
#
# k = 3
# L = 8
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -8.083775753001614
# Time taken for optimization: 7.12199592590332
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -26.270468496829395
# Time taken for optimization: 9.376001596450806
# X_1.shape[0] = 20
# X_0.shape[0] = 35
# Cutted data shape is not enough
#
# k = 2
# L = 4
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -69.58054392436173
# Time taken for optimization: 6.097001791000366
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -87.32854489048448
# Time taken for optimization: 7.87399959564209
# X_1.shape[0] = 224
# X_0.shape[0] = 249
#
# Making hyperplane number 11
# X_train.shape[0] = 3109
# k = 7
# L = 128
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.05849044753297085
# Time taken for optimization: 4.491002321243286
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.028885717787093698
# Time taken for optimization: 5.014999151229858
# X_1.shape[0] = 8
# X_0.shape[0] = 4
# Cutted data shape is not enough
#
# k = 6
# L = 64
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.11870346584092543
# Time taken for optimization: 4.470000505447388
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.043008751442735416
# Time taken for optimization: 5.093999624252319
# X_1.shape[0] = 36
# X_0.shape[0] = 8
# Cutted data shape is not enough
#
# k = 5
# L = 32
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -7.264885883352912
# Time taken for optimization: 4.515000820159912
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.026564913458872443
# Time taken for optimization: 4.255000114440918
# X_1.shape[0] = 10
# X_0.shape[0] = 6
# Cutted data shape is not enough
#
# k = 4
# L = 16
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -5.738490670584208
# Time taken for optimization: 5.218001127243042
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.04304795769505217
# Time taken for optimization: 5.30699896812439
# X_1.shape[0] = 11
# X_0.shape[0] = 6
# Cutted data shape is not enough
#
# k = 3
# L = 8
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -17.579893561026925
# Time taken for optimization: 6.345000267028809
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.039987171423718465
# Time taken for optimization: 5.154001474380493
# X_1.shape[0] = 18
# X_0.shape[0] = 5
# Cutted data shape is not enough
#
# k = 2
# L = 4
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -63.7597977791254
# Time taken for optimization: 9.133000612258911
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -3.0
# Time taken for optimization: 7.316999673843384
# X_1.shape[0] = 122
# X_0.shape[0] = 3
# Cutted data shape is not enough
#
# k = 1
# L = 2
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -198.97684068667047
# Time taken for optimization: 10.936000108718872
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -23.448844698138693
# Time taken for optimization: 10.043999910354614
# X_1.shape[0] = 697
# X_0.shape[0] = 213
#
# Making hyperplane number 12
# X_train.shape[0] = 2412
# k = 7
# L = 128
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.047313835719560965
# Time taken for optimization: 4.477001428604126
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.05591461931171428
# Time taken for optimization: 3.8569979667663574
# X_1.shape[0] = 4
# X_0.shape[0] = 8
# Cutted data shape is not enough
#
# k = 6
# L = 64
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.1590979445770437
# Time taken for optimization: 4.203001260757446
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.011291741840514296
# Time taken for optimization: 4.2900002002716064
# X_1.shape[0] = 5
# X_0.shape[0] = 4
# Cutted data shape is not enough
#
# k = 5
# L = 32
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.06165964539102363
# Time taken for optimization: 5.228002071380615
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.037794267248662194
# Time taken for optimization: 5.290998697280884
# X_1.shape[0] = 5
# X_0.shape[0] = 7
# Cutted data shape is not enough
#
# k = 4
# L = 16
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -4.353886364168652
# Time taken for optimization: 5.255999803543091
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.1278511760222717
# Time taken for optimization: 6.034999847412109
# X_1.shape[0] = 5
# X_0.shape[0] = 16
# Cutted data shape is not enough
#
# k = 3
# L = 8
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -4.0
# Time taken for optimization: 5.304000616073608
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.31709920231708877
# Time taken for optimization: 5.994998931884766
# X_1.shape[0] = 4
# X_0.shape[0] = 19
# Cutted data shape is not enough
#
# k = 2
# L = 4
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -67.52891904280098
# Time taken for optimization: 7.4599997997283936
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.05075186082989243
# Time taken for optimization: 5.439998149871826
# X_1.shape[0] = 165
# X_0.shape[0] = 22
# Cutted data shape is not enough
#
# k = 1
# L = 2
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -135.83451022426067
# Time taken for optimization: 12.290008306503296
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -32.63467106808868
# Time taken for optimization: 10.316993474960327
# X_1.shape[0] = 452
# X_0.shape[0] = 140
#
# Making hyperplane number 13
# X_train.shape[0] = 1960
# k = 7
# L = 128
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.08274345727672859
# Time taken for optimization: 5.309000730514526
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.07474681650939774
# Time taken for optimization: 5.351999521255493
# X_1.shape[0] = 8
# X_0.shape[0] = 14
# Cutted data shape is not enough
#
# k = 6
# L = 64
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.05999996610321905
# Time taken for optimization: 4.577001571655273
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.04571325230039252
# Time taken for optimization: 4.6719982624053955
# X_1.shape[0] = 6
# X_0.shape[0] = 7
# Cutted data shape is not enough
#
# k = 5
# L = 32
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.06217537544526465
# Time taken for optimization: 6.432002305984497
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.04551491212701361
# Time taken for optimization: 5.497996807098389
# X_1.shape[0] = 5
# X_0.shape[0] = 25
# Cutted data shape is not enough
#
# k = 4
# L = 16
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -4.0
# Time taken for optimization: 5.944002151489258
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.05548554042300306
# Time taken for optimization: 5.9459991455078125
# X_1.shape[0] = 4
# X_0.shape[0] = 12
# Cutted data shape is not enough
#
# k = 3
# L = 8
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -4.699163803220456
# Time taken for optimization: 5.987764120101929
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.03347155219252518
# Time taken for optimization: 6.305984973907471
# X_1.shape[0] = 11
# X_0.shape[0] = 8
# Cutted data shape is not enough
#
# k = 2
# L = 4
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -7.0
# Time taken for optimization: 6.435442924499512
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -19.025708598313756
# Time taken for optimization: 7.29630970954895
# X_1.shape[0] = 7
# X_0.shape[0] = 39
# Cutted data shape is not enough
#
# k = 1
# L = 2
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -68.48074032023969
# Time taken for optimization: 10.541495561599731
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -38.61302741909244
# Time taken for optimization: 10.229960203170776
# X_1.shape[0] = 270
# X_0.shape[0] = 159
#
# Making hyperplane number 14
# X_train.shape[0] = 1690
# k = 7
# L = 128
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.04850973522751245
# Time taken for optimization: 4.6823506355285645
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.013312668324057838
# Time taken for optimization: 5.081914663314819
# X_1.shape[0] = 6
# X_0.shape[0] = 3
# Cutted data shape is not enough
#
# k = 6
# L = 64
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.04719523788216679
# Time taken for optimization: 5.582000732421875
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.02879191677280227
# Time taken for optimization: 4.524000644683838
# X_1.shape[0] = 4
# X_0.shape[0] = 6
# Cutted data shape is not enough
#
# k = 5
# L = 32
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.07766570518995161
# Time taken for optimization: 4.988001585006714
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.022385919116891327
# Time taken for optimization: 5.800999641418457
# X_1.shape[0] = 8
# X_0.shape[0] = 11
# Cutted data shape is not enough
#
# k = 4
# L = 16
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.10159912906619195
# Time taken for optimization: 5.162999868392944
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.023199292023851126
# Time taken for optimization: 5.9250006675720215
# X_1.shape[0] = 5
# X_0.shape[0] = 11
# Cutted data shape is not enough
#
# k = 3
# L = 8
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -5.311413460315727
# Time taken for optimization: 5.826124668121338
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.08959835893809515
# Time taken for optimization: 5.3121657371521
# X_1.shape[0] = 12
# X_0.shape[0] = 12
# Cutted data shape is not enough
#
# k = 2
# L = 4
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -7.3119029411361325
# Time taken for optimization: 5.073001146316528
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -19.9205379386064
# Time taken for optimization: 7.7669994831085205
# X_1.shape[0] = 10
# X_0.shape[0] = 40
# Cutted data shape is not enough
#
# k = 1
# L = 2
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -23.712878391284455
# Time taken for optimization: 6.277000188827515
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -81.26525326758622
# Time taken for optimization: 10.559005737304688
# X_1.shape[0] = 33
# X_0.shape[0] = 528
#
# Making hyperplane number 15
# X_train.shape[0] = 1162
# k = 7
# L = 128
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.09151832085858319
# Time taken for optimization: 1.4899957180023193
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.10022522182111579
# Time taken for optimization: 1.7569994926452637
# X_1.shape[0] = 5
# X_0.shape[0] = 13
# Cutted data shape is not enough
#
# k = 6
# L = 64
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.05740169696724638
# Time taken for optimization: 1.815000295639038
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.022367143004182174
# Time taken for optimization: 1.353001356124878
# X_1.shape[0] = 5
# X_0.shape[0] = 7
# Cutted data shape is not enough
#
# k = 5
# L = 32
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.17175074364985024
# Time taken for optimization: 2.010000467300415
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.034612948684579786
# Time taken for optimization: 1.5
# X_1.shape[0] = 6
# X_0.shape[0] = 17
# Cutted data shape is not enough
#
# k = 4
# L = 16
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -3.6074282619267746
# Time taken for optimization: 2.0030019283294678
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.05365128086211247
# Time taken for optimization: 2.1750006675720215
# X_1.shape[0] = 8
# X_0.shape[0] = 11
# Cutted data shape is not enough
#
# k = 3
# L = 8
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -4.5231485671003675
# Time taken for optimization: 1.7790005207061768
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.08770651999150929
# Time taken for optimization: 2.2759993076324463
# X_1.shape[0] = 5
# X_0.shape[0] = 12
# Cutted data shape is not enough
#
# k = 2
# L = 4
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -5.451256372048711
# Time taken for optimization: 2.0719995498657227
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.22107416240512245
# Time taken for optimization: 3.1500043869018555
# X_1.shape[0] = 6
# X_0.shape[0] = 29
# Cutted data shape is not enough
#
# k = 1
# L = 2
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -28.21456429756401
# Time taken for optimization: 3.2869977951049805
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -21.761549579043425
# Time taken for optimization: 3.4240009784698486
# X_1.shape[0] = 40
# X_0.shape[0] = 72
# Cutted data shape is not enough
#
# k = 0
# L = 1
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -128.8130475276239
# Time taken for optimization: 4.196003198623657
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -169.7696693278711
# Time taken for optimization: 2.979996681213379
# X_1.shape[0] = 574
# X_0.shape[0] = 765
#
# Time taken to fit the model: 1276.879537820816

# %%
train_proba = sc.predict_proba(X_train)
test_proba = sc.predict_proba(X_test)
train_preds = sc.predict(X_train)
test_preds = sc.predict(X_test)
print('Train Gini = {}'.format(2 * roc_auc_score(y_train, train_proba) - 1))
print('Test Gini = {}'.format(2 * roc_auc_score(y_test, test_proba) - 1))
print('Train F1 = {}'.format(f1_score(y_train, train_preds)))
print('Test F1 = {}'.format(f1_score(y_test, test_preds)))
print('Train accuracy = {}'.format(accuracy_score(y_train, train_preds)))
print('Test accuracy = {}'.format(accuracy_score(y_test, test_preds)))
# Out:
# Time taken to predict the targets: 13.197998285293579
# Time taken to predict the targets: 5.667002201080322
# Train Gini = 0.8097469149096632
# Test Gini = 0.7958199725148876

# %%
tree = DecisionTreeClassifier(max_depth=8)
tree.fit(X_train, y_train)
train_proba = tree.predict_proba(X_train)
test_proba = tree.predict_proba(X_test)
train_preds = tree.predict(X_train)
test_preds = tree.predict(X_test)
print('Train Gini = {}'.format(2 * roc_auc_score(y_train, train_proba[:, 1]) - 1))
print('Test Gini = {}'.format(2 * roc_auc_score(y_test, test_proba[:, 1]) - 1))
print('Train F1 = {}'.format(f1_score(y_train, train_preds)))
print('Test F1 = {}'.format(f1_score(y_test, test_preds)))
print('Train Accuracy = {}'.format(accuracy_score(y_train, train_preds)))
print('Test Accuracy = {}'.format(accuracy_score(y_test, test_preds)))
# Out:
# Train Gini = 0.8324812079784984
# Test Gini = 0.7513312764409474

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
train_preds = logreg.predict_proba(X_train)
test_preds = logreg.predict_proba(X_test)
train_preds = logreg.predict(X_train)
test_preds = logreg.predict(X_test)
print('Train Gini = {}'.format(2 * roc_auc_score(y_train, train_proba[:, 1]) - 1))
print('Test Gini = {}'.format(2 * roc_auc_score(y_test, test_proba[:, 1]) - 1))
print('Train F1 = {}'.format(f1_score(y_train, train_preds)))
print('Test F1 = {}'.format(f1_score(y_test, test_preds)))
print('Train Accuracy = {}'.format(accuracy_score(y_train, train_preds)))
print('Test Accuracy = {}'.format(accuracy_score(y_test, test_preds)))
# Out:
# Train Gini = 0.6797005984705096
# Test Gini = 0.6773129260866053

# %%
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
train_preds = rf.predict_proba(X_train)
test_preds = rf.predict_proba(X_test)
train_preds = rf.predict(X_train)
test_preds = rf.predict(X_test)
print('Train Gini = {}'.format(2 * roc_auc_score(y_train, train_proba[:, 1]) - 1))
print('Test Gini = {}'.format(2 * roc_auc_score(y_test, test_proba[:, 1]) - 1))
print('Train F1 = {}'.format(f1_score(y_train, train_preds)))
print('Test F1 = {}'.format(f1_score(y_test, test_preds)))
print('Train Accuracy = {}'.format(accuracy_score(y_train, train_preds)))
print('Test Accuracy = {}'.format(accuracy_score(y_test, test_preds)))
# Out:
# Train Gini = 1.0
# Test Gini = 0.8644221389884401

# %%
from lightgbm import LGBMClassifier
lgbm = LGBMClassifier()
lgbm.fit(X_train, y_train)
train_preds = lgbm.predict_proba(X_train)
test_preds = lgbm.predict_proba(X_test)
train_preds = lgbm.predict(X_train)
test_preds = lgbm.predict(X_test)
print('Train Gini = {}'.format(2 * roc_auc_score(y_train, train_proba[:, 1]) - 1))
print('Test Gini = {}'.format(2 * roc_auc_score(y_test, test_proba[:, 1]) - 1))
print('Train F1 = {}'.format(f1_score(y_train, train_preds)))
print('Test F1 = {}'.format(f1_score(y_test, test_preds)))
print('Train Accuracy = {}'.format(accuracy_score(y_train, train_preds)))
print('Test Accuracy = {}'.format(accuracy_score(y_test, test_preds)))
# Out:
# Train Gini = 0.9567622426749023
# Test Gini = 0.8658826224030611
