# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import time
from scipy.optimize import minimize, differential_evolution
from sklearn.metrics import roc_auc_score, f1_score, accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# %%
df = pd.read_table('HTRU2/HTRU_2.arff', sep=',', header=None)

# %%
df.head()
# Out:
#             0          1         2         3         4          5          6  \
# 0  140.562500  55.683782 -0.234571 -0.699648  3.199833  19.110426   7.975532
# 1  102.507812  58.882430  0.465318 -0.515088  1.677258  14.860146  10.576487
# 2  103.015625  39.341649  0.323328  1.051164  3.121237  21.744669   7.735822
# 3  136.750000  57.178449 -0.068415 -0.636238  3.642977  20.959280   6.896499
# 4   88.726562  40.672225  0.600866  1.123492  1.178930  11.468720  14.269573
#
#             7  8
# 0   74.242225  0
# 1  127.393580  0
# 2   63.171909  0
# 3   53.593661  0
# 4  252.567306  0

# %%
df[8].value_counts()
# Out:
# 0    16259
# 1     1639
# Name: 8, dtype: int64

# %%
df.shape
# Out:
# (17898, 9)

# %%
df.head()
# Out:
#             0          1         2         3         4          5          6  \
# 0  140.562500  55.683782 -0.234571 -0.699648  3.199833  19.110426   7.975532
# 1  102.507812  58.882430  0.465318 -0.515088  1.677258  14.860146  10.576487
# 2  103.015625  39.341649  0.323328  1.051164  3.121237  21.744669   7.735822
# 3  136.750000  57.178449 -0.068415 -0.636238  3.642977  20.959280   6.896499
# 4   88.726562  40.672225  0.600866  1.123492  1.178930  11.468720  14.269573
#
#             7  8
# 0   74.242225  0
# 1  127.393580  0
# 2   63.171909  0
# 3   53.593661  0
# 4  252.567306  0

# %%
X = df.drop(columns=[8]).values
y = df[8].values

# %%
for i in range(X.shape[1]):
    X[:,i]=(X[:,i]-X[:,i].min())/(X[:,i].max()-X[:,i].min())

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y)

# %%
X_train.shape
# Out:
# (12528, 8)

# %%
y_train.sum() / len(y_train)
# Out:
# 0.09155491698595147

# %%
from Seniority_committee import Seniority_committee
sc = Seniority_committee(N=200)
# было 500
sc.fit(X_train, y_train, optim_method='TNC', verbose=2)
# Out:
# Making hyperplane number 1
# X_train.shape[0] = 12528
# k = 10
# L = 1024
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -310.34336443762663
# Time taken for optimization: 10.85598373413086
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -13.94785850119079
# Time taken for optimization: 16.78099799156189
# X_1.shape[0] = 330
# X_0.shape[0] = 2332
#
# Making hyperplane number 2
# X_train.shape[0] = 10196
# k = 10
# L = 1024
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -342.9938606655703
# Time taken for optimization: 8.382001161575317
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -114.15597028651874
# Time taken for optimization: 11.657000541687012
# X_1.shape[0] = 382
# X_0.shape[0] = 277
#
# Making hyperplane number 3
# X_train.shape[0] = 9814
# k = 10
# L = 1024
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.013999542524724774
# Time taken for optimization: 5.254000425338745
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -1.6603066336961878
# Time taken for optimization: 8.807999610900879
# X_1.shape[0] = 10
# X_0.shape[0] = 402
#
# Making hyperplane number 4
# X_train.shape[0] = 9412
# k = 10
# L = 1024
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.015776113849159418
# Time taken for optimization: 4.806997060775757
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -1.4696525532913662
# Time taken for optimization: 9.539002418518066
# X_1.shape[0] = 6
# X_0.shape[0] = 206
#
# Making hyperplane number 5
# X_train.shape[0] = 9206
# k = 10
# L = 1024
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.01411416434282196
# Time taken for optimization: 4.655000925064087
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.4015601414980364
# Time taken for optimization: 5.817000389099121
# X_1.shape[0] = 7
# X_0.shape[0] = 483
#
# Making hyperplane number 6
# X_train.shape[0] = 8723
# k = 10
# L = 1024
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.015782501059525687
# Time taken for optimization: 4.110001564025879
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.5235161998850071
# Time taken for optimization: 6.10699987411499
# X_1.shape[0] = 1
# X_0.shape[0] = 1037
#
# Making hyperplane number 7
# X_train.shape[0] = 7686
# k = 10
# L = 1024
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.02249859598826163
# Time taken for optimization: 3.9360010623931885
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.24213615155832974
# Time taken for optimization: 4.705998659133911
# X_1.shape[0] = 1
# X_0.shape[0] = 179
# Cutted data shape is not enough
#
# k = 9
# L = 512
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.022239659525021965
# Time taken for optimization: 3.284998655319214
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.28216214766836756
# Time taken for optimization: 5.4775402545928955
# X_1.shape[0] = 1
# X_0.shape[0] = 554
#
# Making hyperplane number 8
# X_train.shape[0] = 7132
# k = 10
# L = 1024
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.017482721644896764
# Time taken for optimization: 3.902000904083252
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.31272817977264133
# Time taken for optimization: 5.206000566482544
# X_1.shape[0] = 4
# X_0.shape[0] = 272
#
# Making hyperplane number 9
# X_train.shape[0] = 6860
# k = 10
# L = 1024
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.028897644681944813
# Time taken for optimization: 4.702998638153076
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.1200776751682261
# Time taken for optimization: 5.111001491546631
# X_1.shape[0] = 15
# X_0.shape[0] = 194
# Cutted data shape is not enough
#
# k = 9
# L = 512
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.02373084679712694
# Time taken for optimization: 3.7000019550323486
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.10014562056022638
# Time taken for optimization: 6.918999671936035
# X_1.shape[0] = 4
# X_0.shape[0] = 168
# Cutted data shape is not enough
#
# k = 8
# L = 256
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.07620662486521272
# Time taken for optimization: 4.078001022338867
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.4241807252645423
# Time taken for optimization: 7.000000238418579
# X_1.shape[0] = 15
# X_0.shape[0] = 373
#
# Making hyperplane number 10
# X_train.shape[0] = 6487
# k = 10
# L = 1024
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.02641569089412097
# Time taken for optimization: 3.7899703979492188
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.0709211113704618
# Time taken for optimization: 6.7439985275268555
# X_1.shape[0] = 1
# X_0.shape[0] = 15
# Cutted data shape is not enough
#
# k = 9
# L = 512
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.017684138669192013
# Time taken for optimization: 4.626004457473755
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.06599799969278258
# Time taken for optimization: 4.982997894287109
# X_1.shape[0] = 2
# X_0.shape[0] = 107
# Cutted data shape is not enough
#
# k = 8
# L = 256
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.030568422087604085
# Time taken for optimization: 3.397015333175659
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.19379662595152053
# Time taken for optimization: 6.263984680175781
# X_1.shape[0] = 22
# X_0.shape[0] = 256
#
# Making hyperplane number 11
# X_train.shape[0] = 6231
# k = 10
# L = 1024
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.0261705728922274
# Time taken for optimization: 3.6990013122558594
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.01592833105638471
# Time taken for optimization: 2.730999231338501
# X_1.shape[0] = 30
# X_0.shape[0] = 6
# Cutted data shape is not enough
#
# k = 9
# L = 512
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.04506788049811067
# Time taken for optimization: 3.1389989852905273
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.12445085461759016
# Time taken for optimization: 3.7709996700286865
# X_1.shape[0] = 10
# X_0.shape[0] = 137
# Cutted data shape is not enough
#
# k = 8
# L = 256
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.03547668651472785
# Time taken for optimization: 3.017000198364258
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.2751037341864805
# Time taken for optimization: 3.0330026149749756
# X_1.shape[0] = 14
# X_0.shape[0] = 415
#
# Making hyperplane number 12
# X_train.shape[0] = 5816
# k = 10
# L = 1024
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.02348317554764215
# Time taken for optimization: 2.757997512817383
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.17953722707669184
# Time taken for optimization: 2.8530006408691406
# X_1.shape[0] = 7
# X_0.shape[0] = 133
# Cutted data shape is not enough
#
# k = 9
# L = 512
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.10174148539329117
# Time taken for optimization: 3.8499977588653564
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.26483542140016103
# Time taken for optimization: 3.4710171222686768
# X_1.shape[0] = 3
# X_0.shape[0] = 575
#
# Making hyperplane number 13
# X_train.shape[0] = 5241
# k = 10
# L = 1024
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.02986224539149353
# Time taken for optimization: 3.5019986629486084
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.0912170824158598
# Time taken for optimization: 2.7809994220733643
# X_1.shape[0] = 14
# X_0.shape[0] = 139
# Cutted data shape is not enough
#
# k = 9
# L = 512
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.026677652611992387
# Time taken for optimization: 2.9410016536712646
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.08491310523339876
# Time taken for optimization: 3.97499942779541
# X_1.shape[0] = 8
# X_0.shape[0] = 33
# Cutted data shape is not enough
#
# k = 8
# L = 256
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.05981638195273943
# Time taken for optimization: 2.971001625061035
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.042504922646614075
# Time taken for optimization: 2.6190009117126465
# X_1.shape[0] = 18
# X_0.shape[0] = 34
# Cutted data shape is not enough
#
# k = 7
# L = 128
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.026144712287648135
# Time taken for optimization: 3.1849985122680664
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.08104079839146834
# Time taken for optimization: 2.8760008811950684
# X_1.shape[0] = 9
# X_0.shape[0] = 44
# Cutted data shape is not enough
#
# k = 6
# L = 64
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.05359504152042058
# Time taken for optimization: 3.0209991931915283
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -951.1057043605659
# Time taken for optimization: 5.735002756118774
# X_1.shape[0] = 6
# X_0.shape[0] = 2014
#
# Making hyperplane number 14
# X_train.shape[0] = 3227
# k = 10
# L = 1024
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.042644007242504736
# Time taken for optimization: 2.2380027770996094
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.09042559104968619
# Time taken for optimization: 2.5259995460510254
# X_1.shape[0] = 9
# X_0.shape[0] = 116
# Cutted data shape is not enough
#
# k = 9
# L = 512
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.03468752045520577
# Time taken for optimization: 2.9889988899230957
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.03326540834722731
# Time taken for optimization: 2.3590006828308105
# X_1.shape[0] = 9
# X_0.shape[0] = 28
# Cutted data shape is not enough
#
# k = 8
# L = 256
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.030679726170762967
# Time taken for optimization: 2.776998996734619
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.07715393901212625
# Time taken for optimization: 2.6999998092651367
# X_1.shape[0] = 20
# X_0.shape[0] = 169
# Cutted data shape is not enough
#
# k = 7
# L = 128
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.03521220689482507
# Time taken for optimization: 2.2009997367858887
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.10937825944854283
# Time taken for optimization: 2.510000228881836
# X_1.shape[0] = 6
# X_0.shape[0] = 89
# Cutted data shape is not enough
#
# k = 6
# L = 64
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.03453008771099862
# Time taken for optimization: 2.439999580383301
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.20167983811544515
# Time taken for optimization: 3.3709990978240967
# X_1.shape[0] = 13
# X_0.shape[0] = 285
#
# Making hyperplane number 15
# X_train.shape[0] = 2942
# k = 10
# L = 1024
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.029648124947437973
# Time taken for optimization: 1.9510009288787842
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.010635954148535152
# Time taken for optimization: 1.6949992179870605
# X_1.shape[0] = 9
# X_0.shape[0] = 3
# Cutted data shape is not enough
#
# k = 9
# L = 512
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.03428036497997497
# Time taken for optimization: 2.063001871109009
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.04403601183552685
# Time taken for optimization: 2.3399996757507324
# X_1.shape[0] = 6
# X_0.shape[0] = 42
# Cutted data shape is not enough
#
# k = 8
# L = 256
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.07465494064417777
# Time taken for optimization: 2.0619993209838867
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.015436803503354166
# Time taken for optimization: 2.2720024585723877
# X_1.shape[0] = 36
# X_0.shape[0] = 34
# Cutted data shape is not enough
#
# k = 7
# L = 128
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.06753533801803009
# Time taken for optimization: 2.9140071868896484
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.029205150308735016
# Time taken for optimization: 2.482994794845581
# X_1.shape[0] = 7
# X_0.shape[0] = 66
# Cutted data shape is not enough
#
# k = 6
# L = 64
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.029998437844361632
# Time taken for optimization: 2.294996738433838
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.01070900661197928
# Time taken for optimization: 1.815999984741211
# X_1.shape[0] = 34
# X_0.shape[0] = 13
# Cutted data shape is not enough
#
# k = 5
# L = 32
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.0335323019934656
# Time taken for optimization: 2.125002145767212
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -246.10449095765992
# Time taken for optimization: 3.923996925354004
# X_1.shape[0] = 8
# X_0.shape[0] = 795
#
# Making hyperplane number 16
# X_train.shape[0] = 2147
# k = 10
# L = 1024
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.051716955727065236
# Time taken for optimization: 1.9209990501403809
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.12794787676986194
# Time taken for optimization: 2.0129997730255127
# X_1.shape[0] = 32
# X_0.shape[0] = 42
# Cutted data shape is not enough
#
# k = 9
# L = 512
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.014949576244532145
# Time taken for optimization: 1.85599946975708
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.06297821286010258
# Time taken for optimization: 2.0319995880126953
# X_1.shape[0] = 6
# X_0.shape[0] = 40
# Cutted data shape is not enough
#
# k = 8
# L = 256
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.04322133501138786
# Time taken for optimization: 1.8040013313293457
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.13135474656327714
# Time taken for optimization: 1.950998067855835
# X_1.shape[0] = 7
# X_0.shape[0] = 61
# Cutted data shape is not enough
#
# k = 7
# L = 128
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.04492643455074411
# Time taken for optimization: 2.2729990482330322
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.02007353971827796
# Time taken for optimization: 1.693000078201294
# X_1.shape[0] = 8
# X_0.shape[0] = 26
# Cutted data shape is not enough
#
# k = 6
# L = 64
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.043526016910741996
# Time taken for optimization: 1.6820001602172852
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.09225303137136823
# Time taken for optimization: 2.3620009422302246
# X_1.shape[0] = 38
# X_0.shape[0] = 40
# Cutted data shape is not enough
#
# k = 5
# L = 32
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.06662400490836014
# Time taken for optimization: 1.9270060062408447
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.01573575859521699
# Time taken for optimization: 2.0505130290985107
# X_1.shape[0] = 9
# X_0.shape[0] = 14
# Cutted data shape is not enough
#
# k = 4
# L = 16
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -176.08703588574372
# Time taken for optimization: 4.340998411178589
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -358.04258747369755
# Time taken for optimization: 4.048521995544434
# X_1.shape[0] = 446
# X_0.shape[0] = 1133
#
# Making hyperplane number 17
# X_train.shape[0] = 1014
# k = 10
# L = 1024
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -2.468697035030402
# Time taken for optimization: 1.5390355587005615
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.022909629337686217
# Time taken for optimization: 0.9079990386962891
# X_1.shape[0] = 4
# X_0.shape[0] = 28
# Cutted data shape is not enough
#
# k = 9
# L = 512
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.10368853958543192
# Time taken for optimization: 1.9699950218200684
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.01317696396132674
# Time taken for optimization: 1.1089942455291748
# X_1.shape[0] = 4
# X_0.shape[0] = 12
# Cutted data shape is not enough
#
# k = 8
# L = 256
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -1.9964175215050575
# Time taken for optimization: 1.6199584007263184
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.005062087009327539
# Time taken for optimization: 1.6489989757537842
# X_1.shape[0] = 5
# X_0.shape[0] = 2
# Cutted data shape is not enough
#
# k = 7
# L = 128
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.11797691871725602
# Time taken for optimization: 1.8649985790252686
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.006815960171227975
# Time taken for optimization: 1.2040016651153564
# X_1.shape[0] = 45
# X_0.shape[0] = 3
# Cutted data shape is not enough
#
# k = 6
# L = 64
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -3.324829671409703
# Time taken for optimization: 1.5090367794036865
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.013689386690604738
# Time taken for optimization: 1.2479641437530518
# X_1.shape[0] = 5
# X_0.shape[0] = 21
# Cutted data shape is not enough
#
# k = 5
# L = 32
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -5.0
# Time taken for optimization: 1.7370340824127197
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.02327195556124919
# Time taken for optimization: 1.468994379043579
# X_1.shape[0] = 5
# X_0.shape[0] = 29
# Cutted data shape is not enough
#
# k = 4
# L = 16
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -180.03051581548988
# Time taken for optimization: 2.6872618198394775
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.030917172786473993
# Time taken for optimization: 1.3140294551849365
# X_1.shape[0] = 464
# X_0.shape[0] = 26
#
# Making hyperplane number 18
# X_train.shape[0] = 550
# k = 10
# L = 1024
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.09524662681964238
# Time taken for optimization: 1.4400289058685303
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.005450185794510747
# Time taken for optimization: 0.7289726734161377
# X_1.shape[0] = 5
# X_0.shape[0] = 8
# Cutted data shape is not enough
#
# k = 9
# L = 512
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -2.409075910650882
# Time taken for optimization: 1.1980314254760742
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.014848140912831867
# Time taken for optimization: 0.7759664058685303
# X_1.shape[0] = 4
# X_0.shape[0] = 7
# Cutted data shape is not enough
#
# k = 8
# L = 256
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -2.535286987500833
# Time taken for optimization: 1.2740001678466797
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.003683458946735503
# Time taken for optimization: 0.5580339431762695
# X_1.shape[0] = 4
# X_0.shape[0] = 9
# Cutted data shape is not enough
#
# k = 7
# L = 128
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -3.7655393777174337
# Time taken for optimization: 1.439028024673462
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.016386071195897634
# Time taken for optimization: 0.6240060329437256
# X_1.shape[0] = 4
# X_0.shape[0] = 6
# Cutted data shape is not enough
#
# k = 6
# L = 64
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -4.294872714126189
# Time taken for optimization: 1.0569994449615479
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.010743928360598827
# Time taken for optimization: 0.49699831008911133
# X_1.shape[0] = 6
# X_0.shape[0] = 8
# Cutted data shape is not enough
#
# k = 5
# L = 32
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -5.0
# Time taken for optimization: 1.3600070476531982
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.017845521474811863
# Time taken for optimization: 0.7769966125488281
# X_1.shape[0] = 5
# X_0.shape[0] = 16
# Cutted data shape is not enough
#
# k = 4
# L = 16
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -9.0
# Time taken for optimization: 1.5520005226135254
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.006239537470053186
# Time taken for optimization: 0.580040454864502
# X_1.shape[0] = 9
# X_0.shape[0] = 3
# Cutted data shape is not enough
#
# k = 3
# L = 8
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -5.0
# Time taken for optimization: 1.7299511432647705
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -0.1576671928273894
# Time taken for optimization: 0.5870282649993896
# X_1.shape[0] = 5
# X_0.shape[0] = 80
# Cutted data shape is not enough
#
# k = 2
# L = 4
# Optimizing hyperplane for class 1
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -31.07118599413597
# Time taken for optimization: 1.7080178260803223
# Optimizing hyperplane for class 0
# Optimization is started
# First approximation is obtained
# The minimum of the loss function: -101.59963965236153
# Time taken for optimization: 1.1539878845214844
# X_1.shape[0] = 73
# X_0.shape[0] = 215
#
# Time taken to fit the model: 377.4809012413025

# %%
train_proba = sc.predict_proba(X_train)
test_proba = sc.predict_proba(X_test)
train_preds = sc.predict(X_train)
test_preds = sc.predict(X_test)
print('Train Gini = {}'.format(2 * roc_auc_score(y_train, train_proba) - 1))
print('Test Gini = {}'.format(2 * roc_auc_score(y_test, test_proba) - 1))
print('Train F1 = {}'.format(f1_score(y_train, train_preds)))
print('Test F1 = {}'.format(f1_score(y_test, test_preds)))
print('Train accuracy = {}'.format(accuracy_score(y_train, train_preds)))
print('Test accuracy = {}'.format(accuracy_score(y_test, test_preds)))
# Out:
# Time taken to predict the targets: 11.557998418807983
# Time taken to predict the targets: 4.464001417160034
# Time taken to predict the targets: 11.220597982406616
# Time taken to predict the targets: 5.436996698379517
# Train Gini = 0.9659905958377377
# Test Gini = 0.9476436431030972
# Train F1 = 0.8831615120274913
# Test F1 = 0.8870967741935484
# Train accuracy = 0.9782886334610472
# Test accuracy = 0.9791433891992551

# %%
tree = DecisionTreeClassifier(max_depth=4)
tree.fit(X_train, y_train)
train_proba = tree.predict_proba(X_train)
test_proba = tree.predict_proba(X_test)
train_preds = tree.predict(X_train)
test_preds = tree.predict(X_test)
print('Train Gini = {}'.format(2 * roc_auc_score(y_train, train_proba[:, 1]) - 1))
print('Test Gini = {}'.format(2 * roc_auc_score(y_test, test_proba[:, 1]) - 1))
print('Train F1 = {}'.format(f1_score(y_train, train_preds)))
print('Test F1 = {}'.format(f1_score(y_test, test_preds)))
print('Train Accuracy = {}'.format(accuracy_score(y_train, train_preds)))
print('Test Accuracy = {}'.format(accuracy_score(y_test, test_preds)))
# Out:
# Train Gini = 0.9504603452411202
# Test Gini = 0.9452727860611938
# Train F1 = 0.8907178783721994
# Test F1 = 0.8886532343584306
# Train Accuracy = 0.9809227330779055
# Test Accuracy = 0.9804469273743017

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
train_proba = logreg.predict_proba(X_train)
test_proba = logreg.predict_proba(X_test)
train_preds = logreg.predict(X_train)
test_preds = logreg.predict(X_test)
print('Train Gini = {}'.format(2 * roc_auc_score(y_train, train_proba[:, 1]) - 1))
print('Test Gini = {}'.format(2 * roc_auc_score(y_test, test_proba[:, 1]) - 1))
print('Train F1 = {}'.format(f1_score(y_train, train_preds)))
print('Test F1 = {}'.format(f1_score(y_test, test_preds)))
print('Train Accuracy = {}'.format(accuracy_score(y_train, train_preds)))
print('Test Accuracy = {}'.format(accuracy_score(y_test, test_preds)))
# Out:
# Train Gini = 0.9418719478241433
# Test Gini = 0.9458252915862491
# Train F1 = 0.8429672447013487
# Test F1 = 0.8378995433789955
# Train Accuracy = 0.973978288633461
# Test Accuracy = 0.9735567970204841

# %%
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
train_proba = rf.predict_proba(X_train)
test_proba = rf.predict_proba(X_test)
train_preds = rf.predict(X_train)
test_preds = rf.predict(X_test)
print('Train Gini = {}'.format(2 * roc_auc_score(y_train, train_proba[:, 1]) - 1))
print('Test Gini = {}'.format(2 * roc_auc_score(y_test, test_proba[:, 1]) - 1))
print('Train F1 = {}'.format(f1_score(y_train, train_preds)))
print('Test F1 = {}'.format(f1_score(y_test, test_preds)))
print('Train Accuracy = {}'.format(accuracy_score(y_train, train_preds)))
print('Test Accuracy = {}'.format(accuracy_score(y_test, test_preds)))
# Out:
# Train Gini = 0.9999996935806761
# Test Gini = 0.9480148968156348
# Train F1 = 0.9995638901003052
# Test F1 = 0.888888888888889
# Train Accuracy = 0.9999201787994891
# Test Accuracy = 0.9806331471135941

# %%
from lightgbm import LGBMClassifier
lgbm = LGBMClassifier()
lgbm.fit(X_train, y_train)
train_proba = lgbm.predict_proba(X_train)
test_proba = lgbm.predict_proba(X_test)
train_preds = lgbm.predict(X_train)
test_preds = lgbm.predict(X_test)
print('Train Gini = {}'.format(2 * roc_auc_score(y_train, train_proba[:, 1]) - 1))
print('Test Gini = {}'.format(2 * roc_auc_score(y_test, test_proba[:, 1]) - 1))
print('Train F1 = {}'.format(f1_score(y_train, train_preds)))
print('Test F1 = {}'.format(f1_score(y_test, test_preds)))
print('Train Accuracy = {}'.format(accuracy_score(y_train, train_preds)))
print('Test Accuracy = {}'.format(accuracy_score(y_test, test_preds)))
# Out:
# Train Gini = 0.9997881110374767
# Test Gini = 0.9635196351963518
# Train F1 = 0.9801148917366328
# Test F1 = 0.8990435706695006
# Train Accuracy = 0.9964080459770115
# Test Accuracy = 0.9823091247672253
